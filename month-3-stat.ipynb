# %%
import numpy as N

# %%
D = [45 , 46 , 47 , 48 , 49]

# %%
Mean = N.mean(D)

# %%
Median = N.median(D)

# %%
STD = N.std(D)

# %%
print(Mean)
print("\n")
print(Median)
print("\n")
print(STD)
# Out:
# 47.0
#
#
# 47.0
#
#
# 1.4142135623730951
